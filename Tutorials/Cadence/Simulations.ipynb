# %%
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd

# %%
import healpy as hp

# %%
from opsimsummary import OpSimOutput

# %%
from snsims import PowerLawRates, SALT2_MMDist, SimpleSALTDist, SimulationTile

# %%
zdist = PowerLawRates(rng=np.random.RandomState(1),
                      fieldArea=hp.nside2pixarea(nside=4, degrees=True),
                      zbinEdges=np.arange(0.0001, 1.1, 0.1))

# %%
opsimout = OpSimOutput.fromOpSimDB('minion_1016_sqlite.db', subset='combined')
# Out:
#  reading from database sqlite:///minion_1016_sqlite.db
# SELECT * FROM Summary WHERE PROPID in (56, 54)

# %%
NSIDE = 256

# %%
import opsimsummary as oss

# %%
import os

# %%
oss.__path__
# Out:
# ['/Users/rbiswas/.local/lib/python2.7/site-packages/opsimsummary']

# %%
healpixelizedOpSim = os.path.join(oss.__path__[0], 'example_data', 'healpixels_micro.db')

# %%
healpixelizedOpSim = os.path.join('/Users/rbiswas/data/LSST/OpSimData/healpixelized_MINION_1016_256.db'
                                  )

# %%
healpixelizedOpSim
# Out:
# '/Users/rbiswas/data/LSST/OpSimData/healpixelized_MINION_1016_256.db'

# %%
def func(i):
    tileID = i
    simTile = SimulationTile(SimpleSALTDist,
                                    NSIDE=NSIDE,
                                    tileID=tileID,
                                    hpOpSim=healpixelizedOpSim,
                                    rate=PowerLawRates,
                                    allPointings=opsimout)
    print(simTile.lc(i).lightCurve)
    simTile.writeTile(fileName='simTiles_{}.hdf'.format(i))

# %%
import time

# %%
tstart = time.time()
func(1)
tend = time.time()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-96-1752f0b213a0> in <module>()
#       1 tstart = time.time()
# ----> 2 func(1)
#       3 tend = time.time()
#
# <ipython-input-91-d600307a0693> in func(i)
#       7                                     rate=PowerLawRates,
#       8                                     allPointings=opsimout)
# ----> 9     print(simTile.lc(i).lightCurve)
#      10     simTile.writeTile(fileName='simTiles_{}.hdf'.format(i))
#
# /Users/rbiswas/.local/lib/python2.7/site-packages/snsims/simulations.pyc in lc(self, snid)
#     329
#     330     def lc(self, snid):
# --> 331         sn = self.SN(snid, timeRange='model')
#     332         lcMinTime = sn.mintime()
#     333         lcMaxTime = sn.maxtime()
#
# /Users/rbiswas/.local/lib/python2.7/site-packages/snsims/simulations.pyc in SN(self, snid, timeRange)
#     295
#     296     def SN(self, snid, timeRange='model'):
# --> 297         mySNParams = self.snParamTable.ix[snid]
#     298         sn = SNObject(ra=mySNParams.ra, dec=mySNParams.dec)
#     299         sncosmo_params = self.getSNCosmoParamDict(mySNParams, sn)
#
# /usr/local/miniconda/lib/python2.7/site-packages/pandas/core/indexing.pyc in __getitem__(self, key)
#      76         else:
#      77             key = com._apply_if_callable(key, self.obj)
# ---> 78             return self._getitem_axis(key, axis=0)
#      79
#      80     def _get_label(self, label, axis=0):
#
# /usr/local/miniconda/lib/python2.7/site-packages/pandas/core/indexing.pyc in _getitem_axis(self, key, axis)
#    1016                     return self._get_loc(key, axis=axis)
#    1017
# -> 1018             return self._get_label(key, axis=axis)
#    1019
#    1020     def _getitem_iterable(self, key, axis=0):
#
# /usr/local/miniconda/lib/python2.7/site-packages/pandas/core/indexing.pyc in _get_label(self, label, axis)
#      91             raise IndexingError('no slices here, handle elsewhere')
#      92
# ---> 93         return self.obj._xs(label, axis=axis)
#      94
#      95     def _get_loc(self, key, axis=0):
#
# /usr/local/miniconda/lib/python2.7/site-packages/pandas/core/generic.pyc in xs(self, key, axis, level, copy, drop_level)
#    1747                                                       drop_level=drop_level)
#    1748         else:
# -> 1749             loc = self.index.get_loc(key)
#    1750
#    1751             if isinstance(loc, np.ndarray):
#
# /usr/local/miniconda/lib/python2.7/site-packages/pandas/indexes/base.pyc in get_loc(self, key, method, tolerance)
#    1945                 return self._engine.get_loc(key)
#    1946             except KeyError:
# -> 1947                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    1948
#    1949         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4154)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4018)()
#
# pandas/hashtable.pyx in pandas.hashtable.Int64HashTable.get_item (pandas/hashtable.c:6610)()
#
# pandas/hashtable.pyx in pandas.hashtable.Int64HashTable.get_item (pandas/hashtable.c:6554)()
#
# KeyError: 1

# %%
# !ls -ltr
# Out:
# total 398152
# -rw-r--r--   1 rbiswas  staff     168173 Nov 16 05:26 Cadence_And_OpSim.ipynb
# lrwxr-xr-x   1 rbiswas  staff         56 Nov 16 06:24 minion_1016_sqlite.db -> /Users/rbiswas/data/LSST/OpSimData/minion_1016_sqlite.db
# drwxr-xr-x   8 rbiswas  staff        272 Nov 16 06:25 TransientsUPS
# -rw-r--r--   1 rbiswas  staff     312598 Nov 16 06:25 TransientMontewUPS.ipynb
# drwxr-xr-x  10 rbiswas  staff        340 Nov 16 06:31 TransientsMonte
# -rw-r--r--   1 rbiswas  staff     158433 Nov 16 06:32 transientMonteMetric.ipynb
# drwxr-xr-x   9 rbiswas  staff        306 Nov 16 06:38 newmetric_test
# -rw-r--r--   1 rbiswas  staff     209778 Nov 16 06:39 Writing A New Metric.ipynb
# -rw-r--r--   1 rbiswas  staff       1032 Nov 16 07:24 simTiles_0.hdf
# -rw-r--r--   1 rbiswas  staff  202912768 Nov 16 07:38 healpixels_micro.db
# -rw-r--r--   1 rbiswas  staff      46658 Nov 16 07:39 Simulations.ipynb
# -rw-r--r--   1 rbiswas  staff      17208 Nov 16 07:41 simTiles_0_params.hdf

# %%
du -h simTiles_0.hdf
# Out:
#   File "<ipython-input-90-02ca8a0a107f>", line 1
#     du -h simTiles_0.hdf
#                    ^
# SyntaxError: invalid syntax

# %%
df = pd.read_hdf('simTiles_0.hdf', 'tiles_0')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-83-b9e8465aeb7e> in <module>()
# ----> 1 df = pd.read_hdf('simTiles_0.hdf', 'tiles_0')
#
# /usr/local/miniconda/lib/python2.7/site-packages/pandas/io/pytables.pyc in read_hdf(path_or_buf, key, **kwargs)
#     328                                  'multiple datasets.')
#     329             key = keys[0]
# --> 330         return store.select(key, auto_close=auto_close, **kwargs)
#     331     except:
#     332         # if there is an error, close the store
#
# /usr/local/miniconda/lib/python2.7/site-packages/pandas/io/pytables.pyc in select(self, key, where, start, stop, columns, iterator, chunksize, auto_close, **kwargs)
#     660         group = self.get_node(key)
#     661         if group is None:
# --> 662             raise KeyError('No object named %s in the file' % key)
#     663
#     664         # create the storer and axes
#
# KeyError: 'No object named tiles_0 in the file'

# %%
df
# Out:
#              M       Mabs         c         mB            t0            x0  \
# snid
# 0    -0.500728 -19.592450  0.132919  19.874810  9.714095e+06  1.770697e-04
# 1    -0.135948 -19.537633  0.042043  20.998748  1.007192e+06  6.310553e-05
# 2    -0.591368 -19.942084  0.121033  20.966110  2.026352e+06  6.450586e-05
# 15    1.265319  0.537447  44.893018  0.172898
# 16    0.588721  0.508901  44.998652  0.277421
# 17    0.315359  0.541464  45.005850  0.087968
# 18    0.350387  0.557353  45.088926  0.193214
# 19    0.358654  0.577413  44.977330  0.254360
# 20   -0.364698  0.600331  44.937488  0.127818
# 21   -0.877513  0.601443  45.001235  0.252566
# 22    0.279958  0.600058  44.975098  0.047661
# 23   -1.604253  0.575616  45.024233  0.250282
# 24    0.863365  0.626692  45.047671  0.220437
# 25   -1.799197  0.591299  44.951793  0.212138
# 26   -0.686527  0.689249  44.976970  0.238114
# 27    0.001373  0.678964  44.949199  0.055990
# 28   -0.777752  0.650821  45.003032  0.093773
# 29    0.101992  0.686966  44.901991  0.160760
# ...        ...       ...        ...       ...
# 95    0.614850  1.271529  44.961753  0.211286
# 96    1.096760  1.303503  44.966678  0.201295
# 97    0.879824  1.300406  44.919518  0.222789
# 98   -0.685424  1.276652  45.034988  0.142962
# 99   -0.844288  1.325395  44.978401  0.098390
# 100   1.618855  1.302978  44.957378  0.058689
# 101  -0.646047  1.297494  44.979261  0.236766
# 102   0.763493  1.301294  44.896962  0.182620
# 103   2.630077  1.311109  45.025247  0.057458
# 104  -0.850503  1.281836  45.109510  0.119235
# 105   0.374015  1.287875  44.946361  0.200662
# 106   0.088428  1.274689  45.059321  0.132501
# 107  -0.504372  1.273034  44.925513  0.107734
# 108  -0.749583  1.396106  45.097525  0.140873
# 109  -0.989000  1.381769  45.123859  0.177904
# 110   0.796817  1.364332  45.001237  0.012200
# 111  -0.357308  1.345919  45.020700  0.245556
# 112   0.864475  1.347805  45.075228  0.218705
# 113   1.196009  1.334062  45.060731  0.059451
# 114   0.351487  1.360409  45.095863  0.202646
# 115   0.399268  1.351826  44.905175  0.152614
# 116  -0.216308  1.378744  45.104396  0.089624
# 117   1.731195  1.356443  44.946769  0.157756
# 118   1.864474  1.342572  45.055587  0.170541
# 119  -0.602273  1.331728  44.970473  0.039169
# 120  -1.083391  1.334707  44.892175  0.132928
# 121  -0.619794  1.377557  45.086405  0.224763
# 122  -0.057219  1.361759  45.045827  0.198426
# 123  -0.238896  1.367561  44.995331  0.026113
# 124  -0.249013  1.392767  44.999191  0.044910
#
# [125 rows x 10 columns]

# %%
plt.hexbin(df.ra, df.dec)

# %%
df = pd.read_hdf('simTiles_0.hdf')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-80-dcc36151dd9b> in <module>()
# ----> 1 df = pd.read_hdf('simTiles_0.hdf')
#
# /usr/local/miniconda/lib/python2.7/site-packages/pandas/io/pytables.pyc in read_hdf(path_or_buf, key, **kwargs)
#     325             keys = store.keys()
#     326             if len(keys) != 1:
# --> 327                 raise ValueError('key must be provided when HDF file contains '
#     328                                  'multiple datasets.')
#     329             key = keys[0]
#
# ValueError: key must be provided when HDF file contains multiple datasets.
